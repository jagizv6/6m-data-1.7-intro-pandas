# %%
import pandas as pd
# A simple list of data
data = [10, 20, 30, 40]
# Converting it to a Pandas Series
s = pd.Series(data, index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
